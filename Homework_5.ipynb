# %% [markdown]
# # Homework 5 - Visit the Wikipedia hyperlinks graph!
#
# ## Our team (group 29):
#
# - Elena lavinia Diaconu
# - Giulia Scikibu Maravalli
# - Hassan Ismail
#
# *Libraries*:

# %%
#import libraries:

import numpy as np
from collections import defaultdict
import pandas as pd
import re
import networkx as nx
import functions as func

# %% [markdown]
# ## RQ1
#
# Our first assignment is to built a graph where the nodes $(V)$ are wikipedia ariticles and the edges $(E)$ are the hyperlink among them, i.e. $G=(V,E)$.
# In order to make this graph, we based on [wiki-topcats-reduced.txt](https://drive.google.com/file/d/1ghPJ4g6XMCUDFQ2JPqAVveLyytG8gBfL/view). Taking information from this file, we create a dictionary, called edges, that has as key an article and as value a list of the other articles towards which the key article is connected. At the same time, we also create a set (nodes), where we collect all the unique articles (i.e. nodes) that appears in our graph.

# %%
f = open('wiki-topcats-reduced.txt')
edges = defaultdict(list)
nodes = set()

for line in f:
    (key, val) = line.split()
    
    #dictionary edges has as key the wiki page, as value a list of pages linked to the key page
    edges[int(key)].append(int(val))
    
    #add key and value to nodes (both key and values are wiki pages)
    #nodes is a set so if a page is already present it will not be added again
    nodes.add(int(key))
    nodes.add(int(val))

edges = dict(edges) #edges from default dictionary to dictionary

# %% [markdown]
# We used the information from *edges* dicitonary and *nodes* set to provide same basic information about the graph:
#
# - If it is direct or not
# - The number of nodes
# - The number of edges
# - The average node degree. Is the graph dense?

# %% [markdown]
# **Directed or not?**
#
# First of all we want to check if the graph is directed or undirected. A graph is undirected if the edges have no direction (i.e. there two-way relationship between linked nodes), in simple terms if node A is connected to node B, also node B is connected to node A, and it applies to all the nodes in the graph. Therefore, if we know that just a couple of nodes are not mutually connected (e.g. A -> B, but B not connected to A), we can tell that the graph is directed.
# In our code we use the *edges* dictionary (reminder: key is a node and the value is a list of nodes towards which the key node is connected), we itererate through nodes in keys and values to see if they are mutually conncected, if not or if there is a KeyError (i.e. that node not exist as a key, so it is not linked toward anything) we know that the graph is directed and we print it, if nothing is printed out after iteration the graph is uniderected.
# In our case the graph is directed.

# %%
#iterate through nodes
for key, val in edges.items():
    try:
        for node in val:
            #if the key node is not in the list of nodes toward its linked node is connected
            #it means they are not mutually connected, then the graph is directed.
            if key not in edges[node]: 
                break
                print('Directed Graph')
    #if a KeyError is raised, that node not exist as a key, so it is not linked toward anything
    except KeyError:
        print('Directed Graph')
        break
# Out:
# Directed Graph

# %% [markdown]
# **Number of nodes**
#
# We compute the total number of nodes of our graph by taking the length of *nodes* set. This set, created in the first chunck of this script, is made of all the nodes that appear in *wiki-topcats-reduced.txt*.

# %%
#The number of nodes
print('The number of nodes:', len(nodes))
# Out:
# The number of nodes: 461193

# %% [markdown]
# **Number of edges and average node degree**
#
# Now taking information from edges dictionary we create another dictionary *degree*, where we have as key the page (as in edges dict) and as value the degree associated to that page (we assume that every edge has $degree = 1$, in each iteration we also sum the degrees, so that at the end of the for loop, we get in the variable *sum_degree* the sum of all node degrees (since every degree is equal to 1, the sum of all degree correspond to the sum of all the edges).

# %%
degree = {}
sum_degrees = 0
for key, value in edges.items():
    degree[key]=len(value)
    sum_degrees += degree[key]

#The number of edges
tot_edges = sum_degrees
print('Number of edges:', tot_edges)

#The average node degree
average_degree = sum_degrees/len(nodes)
print('The average node degree:', average_degree)
# Out:
# Number of edges: 2645247
# The average node degree: 5.735661642739591

# %% [markdown]
# **Is the graph dense?**
#
# A graph is *dense* when its number of edges is close to the maximal number of edges. The graph density of a directed graph is defined as:
# $$D=\frac{|E|}{|V||(V-1)|}$$
# Graph desity is a value between 0 and 1, where 1 is the maximal density and 0 is minimal density.

# %%
#maximal n. of edges:
max_edgs_n = (len(nodes)*(len(nodes)-1))
print('Maximal number of edges', max_edgs_n)

#graph density
density = tot_edges/max_edgs_n
print('Graph density is ', density)
# Out:
# Maximal number of edges 212698522056
# Graph density is  1.2436602635647606e-05

# %% [markdown]
# As shown above the graph density is about 0.0000124, in light of it, we can claim that **the graph is not dense**.

# %% [markdown]
# ## RQ2
#
# ### Ranking of categories
#
# Now we have to rank all categories of our articles according to the distance from an input category, the distance is computed as follow:
# $$distance(C_{0}, C_{1}) = median(ShortestPath(C_{0}, C_{1}))$$
#
# At first we need to load data from [wiki-topcats-categories.txt](https://snap.stanford.edu/data/wiki-topcats.html), in this file we have the name of the category with its corresponding articles, relying on this file we create a dictionary, named *categories*, in which the keys are the names of the categories and the values are lists of the corresponding articles.
# We keep just the categories with more than 3500 articles, then we remove from the remaining categories also all the nodes that are isolated (i.e. no edges incoming, no edges outgoing), in fact they do not provide useful information to our analysis since thay do not have edges. However we record how many isolated nodes we have removed from any category in isolated_nod dictionary (key is name of category, value the number of isolated nodes). Later, we will consider them as nodes with infinite distances and add them directly in the shortestpath list.
#
# We saved this dictionary in a file (*categories.txt*), that we include in our repositiory, feel free to take a look at it.

# %%
f = open('wiki-topcats-categories.txt')
categories = {}
isolated_nod = {}

for line in f.readlines():
    list_of_art = [int(s) for s in line.split() if s.isdigit()]
    #keep just categories with more than 3500 articles
    if len(list_of_art) > 3500:
        #estract the name of the category with regular expression
        cat = re.search(':(.+?);', line)
        cat = cat.group(1)
        #remove nodes that are isolated (no edges incoming, no edges outgoing)
        len_cat = len(set(list_of_art))
        categories[cat] = list(set(list_of_art).intersection(nodes))
        isolated_nod[cat] = len_cat - len(categories[cat])

#save the dictionary as a txt file
func.save_dict('categories.txt', categories)

# %% [markdown]
# Then, we create a dictionary *shortest* where the keys are the nodes present in our graph and the values are empty lists, we will fill them after with the shortest paths.

# %%
shortest ={}
for i in nodes:
    shortest[i] = []

# %% [markdown]
# Now we define a Breadth First Search function, called *bfs* to compute the shortest path. This function takes as input an adjacency list (i.e. our *edges* dictionary) and a node. It will keep itarating from the starting node to all its children and so on, untill it reaches all the node than can be reachable from the starting one, during this process we take record of the depth (i.e. path): if the child node is a key of our *shortest* dictionary, we append to the value (that is a list), the depth. It is possible to see the code of our bfs in functions.py file.

# %% [markdown]
# We take a category in input:

# %%
input_ = input('Enter an input category: ')
# Out:
# Enter an input category: Year_of_birth_unknown

# %% [markdown]
# Now we compute the *bfs* for all the nodes of our input category. During the iteration the *shortest* dictionary will be updated, at the end this dictionary will have this structure: the key are all the nodes, the values are lists in which the elements are the shortest path between the key node and the node from the input category, if a key node has as value an empty list it means that node has no link with none of the nodes in the input category.
# We save the resulting *shortest* distance in a txt file (*C0_path.txt*), attached in our repository.

# %%
C0 = categories[input_]

for art in C0:
    shortest = func.bfs(edges, art, shortest)

#save shortest dictionary to a file
func.save_dict('C0_path.txt', shortest)

# %% [markdown]
# In order not to rexecute the previous code, we include here the code to reload from *C0_path.txt*, *shortest* in the right format (i.e. a dictionary):

# %%
#load back shortest from file as a dictionary

shortest = func.load_saved_dict('C0_path.txt')
shortest = {int(k):v for k,v in shortest.items()} #convert key into integers

# %% [markdown]
# Finally the comparison between categories: for every article of one category we retrive the corresponding value in *shortest* dictionary, i.e. the list with all the path between that article and all the article in the input category (C0), we append all those list in a bigger one (list for the whole category), called *distances*, and we calculate the median over it.
#
# Our analysis, untill now, has considered the nodes that are connected, to take into account also the nodes that are not conncted (infinite distance) with with the article of the iteration, we use this strategy: we compute the product between the lengths of input category and the one of the other category that is in the iteration, in this way we know how long should be our list of shortest paths, if this list (we called it *distance*) is smaller than that length, we calculate the difference and append as many infinite values as the value of the difference to the shortest path list (i.e. the one named *distances*). In addition, we consider how many isolated node are in the category of interest, retrieving them from *isolated_nod* dictionary. Since these nodes have no edges incoming/outgoing, surely they are not connected with any node of the imput category, therefore we add to the shortest path list as many inf value as the number of isolated nodes.
# Finally, we compute the median over that list. Then recording the median value, we rank the category.
# We decide to order the categories, fist taking into account the value of median, and second (since several categories has the same median) by the ratio of n. of infinite values over the total number of elements in its shortest path list. We opted for this method of ranking, beacuse we belive that between two categories with the same median, the one with more infinite values, is as consequence less connected to the input category.
#
# We store the result in a form of a tuple in which the first element is the name of the category and the second is the result of the median, then we append the tuple to *vector* list.
#
# NOTE: all this code is inside the definition of function *distances_vector* in functions.py file.

# %%
vector = func.distances_vector(categories, shortest, input_, C0, isolated_nod)

# %% [markdown]
# We save *vector* list inside a txt file, so we can just use the file instead of rexecute the code above, and load it back as a list.

# %%
#save vector list to a file

func.save_list('unsort_vec.txt', vector)

# %%
#load vecotor from the file as a list

vector1 = func.load_saved_list('unsort_vec.txt')

# %% [markdown]
# In conclusion, we sort the *vector1* list, according to the value of the median, and print it out, keeping, as requested, just the names of the categories.

# %%
vector = sorted(vector, key=lambda x: (x[1], x[2]))
block_ranking = []
for i in vector:
    block_ranking.append(i[0]) #block ranking with sorted categories without showing median values

vector
# Out:
# [('Year_of_birth_unknown', -1, 0),
#  ('American_film_actors', 6, 0.3015),
#  ('English-language_films', 6.0, 0.3095),
#  ('Members_of_the_United_Kingdom_Parliament_for_English_constituencies',
#   7,
#   0.2947),
#  ('Indian_films', 7, 0.301),
#  ('American_films', 7, 0.3022),
#  ('English_television_actors', 7, 0.3318),
#  ('American_television_actors', 7.0, 0.3332),
#  ('British_films', 7, 0.3501),
#  ('Black-and-white_films', 7, 0.3506),
#  ('American_Jews', 7, 0.4044),
#  ('Article_Feedback_Pilot', 7, 0.4314),
#  ('Rivers_of_Romania', 8.0, 0.3377),
#  ('English-language_albums', 8, 0.4273),
#  ('People_from_New_York_City', 8.0, 0.4543),
#  ('Debut_albums', 9.0, 0.4448),
#  ('Windows_games', inf, 0.5012),
#  ('Fellows_of_the_Royal_Society', inf, 0.5092),
#  ('Place_of_birth_missing_(living_people)', inf, 0.5172),
#  ('Living_people', inf, 0.5258),
#  ('The_Football_League_players', inf, 0.5326),
#  ('Harvard_University_alumni', inf, 0.5424),
#  ('American_military_personnel_of_World_War_II', inf, 0.5458),
#  ('English_footballers', inf, 0.546),
#  ('Year_of_birth_missing_(living_people)', inf, 0.5501),
#  ('Major_League_Baseball_pitchers', inf, 0.5622),
#  ('English_cricketers', inf, 0.5695),
#  ('Association_football_forwards', inf, 0.5927),
#  ('Association_football_defenders', inf, 0.6262),
#  ('Association_football_midfielders', inf, 0.6284),
#  ('Association_football_goalkeepers', inf, 0.6397),
#  ('Year_of_birth_missing', inf, 0.7607),
#  ('Asteroids_named_for_people', inf, 0.7871),
#  ('Year_of_death_missing', inf, 0.8017),
#  ('Main_Belt_asteroids', inf, 0.8191)]

# %%
func.save_list('block_ranking.txt', block_ranking)

# %%
#load vector from the file as a list

block_ranking = func.load_saved_list('block_ranking.txt')
block_ranking
# Out:
# ['Year_of_birth_unknown',
#  'American_film_actors',
#  'English-language_films',
#  'Members_of_the_United_Kingdom_Parliament_for_English_constituencies',
#  'Indian_films',
#  'American_films',
#  'English_television_actors',
#  'American_television_actors',
#  'British_films',
#  'Black-and-white_films',
#  'American_Jews',
#  'Article_Feedback_Pilot',
#  'Rivers_of_Romania',
#  'English-language_albums',
#  'People_from_New_York_City',
#  'Debut_albums',
#  'Windows_games',
#  'Fellows_of_the_Royal_Society',
#  'Place_of_birth_missing_(living_people)',
#  'Living_people',
#  'The_Football_League_players',
#  'Harvard_University_alumni',
#  'American_military_personnel_of_World_War_II',
#  'English_footballers',
#  'Year_of_birth_missing_(living_people)',
#  'Major_League_Baseball_pitchers',
#  'English_cricketers',
#  'Association_football_forwards',
#  'Association_football_defenders',
#  'Association_football_midfielders',
#  'Association_football_goalkeepers',
#  'Year_of_birth_missing',
#  'Asteroids_named_for_people',
#  'Year_of_death_missing',
#  'Main_Belt_asteroids']

# %% [markdown]
# ### Ranking of articles
#
# Once we obtained the block_ranking vector of the categories, we want to rank the articles within each category.
#
# In order to do so, we need to prepare our data. First, according to the order given by the block ranking, we create a list of lists, named *cats*, in which every list is the articles(i.e. nodes) that belongs to a category: e.g. *cats[0]* is a list of all article that are in the first category in the block ranking (i.e. the input category).
#
# Further, in the assignment it is written that in the case an article belongs to more than one category, *"if the article belongs to the input category, it belongs to that one. Otherwise, the category of the article will correspond, among the categories it belongs to, to the closest to the input category"*. To allocate correctly the articles that appears in different categories, we take all the articles that are in a category and check if they have appeard in previous categories (`confr = confr.union(cats[i-1])`) if so, we remove the article from the current category (`cats[i] = list(set(cats[i])-confr`).

# %%
#list of articles for each category
cats = []
for name in block_ranking:
    cats.append(categories[name])
    
#allocate articles in right category
for i in range(1, len(cats)):
    if i == 1:
        confr = set(cats[0])
    else:
        confr = confr.union(cats[i-1])
    cats[i] = list(set(cats[i])-confr)

# %% [markdown]
# To find the subgraph induced by a category, we used the library *networkx*, but before comupting subgraph, we need to create our graph (actually a DiGraph, directed graph) in networkx: we build an empty directed graph, then we fill with the set of all our articles, named *nodes* (created in RQ1),  and then with edges. To make the edges readable to networkx we had to present them as a list of tuple, where the first element is the start node, and the second is the end node, for this reason we open again *wiki-topcats-reduced.txt*, and create a list of tuples, as explained.

# %%
#create a container of edges as a list of tuples
f = open('wiki-topcats-reduced.txt')
edges_1 = []
for line in f:
    (key, val) = line.split()
    tup = (int(key),int(val))
    edges_1.append(tup)

#create graph, fill it with nodes and edges
G = nx.DiGraph()
G.add_nodes_from(nodes)
G.add_edges_from(edges_1)

# %% [markdown]
# Thinking about the future, we know that we are not going to show up a rank with the numbers corresponding to each article, instead we want to make the visualistaion easy to understand, so we want to print a rank of titles of the articles. With this aim, we decide to create the dictionary *page_names*, where the keys are the number corresponding to each article, and the values their title.

# %%
f = open('wiki-topcats-page-names.txt')
page_names = {}

for line in f:
    (key, val) = line.split(' ', 1)
    page_names[int(key)] = val.strip('\n')

# %% [markdown]
# **Step 1**
# We compute the subgraph induced by C0: create a subgraph with the nodes of C0, for every node we keep record of the its degree with `sub.in_degree(nod)`, putting the node as a key and its degree as a value of c dictionary.
# We also started to built our *score article* in the form of a dictionary in which the key is the name of the category, and the value is a list of article names (thanks to *page_names* dictionary created before) ranked by degree values.

# %%
score_art = defaultdict(list)
c = {}
sub = nx.subgraph(G,cats[0])
key = block_ranking[0]
for nod in cats[0]:
    c[nod] = sub.in_degree(nod)
    name = page_names[nod] 
    score_art[key].append((name, c[nod])) 
score_art[key].sort(key=lambda x: x[1], reverse = True)

# %% [markdown]
# **Step 2-3**
# We now repeat the same operations did in the previous step for the other categories, the only difference is that this time, we have to compute the degree taking into account the fact that if an edges come from a node for which we already know the degree, the edges will be weighted with that degree.
#
# We iterate through category, and then through all the nodes inside that category. At the beginnig, we assign to the node the degree given by `sub.in_degree(nod)`, however this line of code consider only the edges incoming from nodes in the same subgraph (i.e. category). To take into account edges incomig from other nodes, we calculate the set difference between *G.in_edges(nod)* and *sub.in_edges(nod)*, i.e. the difference between the edges coming from the whole graph versus the edges coming from inside the subgraph, this set difference returns, between the results, the starting nodes from the other categories. From the homework assignment, we know that we have to consider the degree of those *external* nodes only if their categories have already been processed, we check that with `if item[0] in c.keys()`, if that the case, we add to the our node degree also the degree of those starting nodes (`c[nod] += c[item[0]]`).
#
# Then as we did in step one, we save the node degree in c dictionary, and update the *score_art* list with ranked articles.

# %%
for n in range(1, len(cats)):
    key = block_ranking[n]
    sub = nx.subgraph(G,cats[n])
    for nod in cats[n]:
        c[nod] = sub.in_degree(nod)
        diff = set(G.in_edges(nod))-set(sub.in_edges(nod))
        if len(diff) > 0:
            for item in diff:
                if item[0] in c.keys():
                    c[nod] += c[item[0]]                    
        name = page_names[nod]
        score_art[key].append((name, c[nod]))
    score_art[key].sort(key=lambda x: x[1], reverse = True)

# %%
#convert from defaultdict to dict
score_art1 = dict(score_art)

#save score_art dictionary to a file
func.save_dict('score_art.txt', score_art1)

# %%
#load score_art dictionary from file back to dict type
score_art1 = func.load_saved_dict('score_art.txt')

# %% [markdown]
# For visualisation purposes we show our score articles as a dataframe.
# Note: None values appears because same categories has more articles than others.

# %%
df_score = pd.DataFrame.from_dict(score_art1, orient='index')
df_score
# Out:
#                                                                                           0       \
# Year_of_birth_unknown                                                     [Diogenes Lartius, 21]
# American_film_actors                                                           [John Wayne, 278]
# English-language_films                                         [Gone with the Wind (film), 1243]
# Members_of_the_United_Kingdom_Parliament_for_En...                     [Winston Churchill, 2788]
# Indian_films                                                                      [Dhamaal, 682]
# American_films                                                   [Bonnie and Clyde (film), 4233]
# English_television_actors                                                      [Bob Hope, 13106]
# American_television_actors                                                   [Will Smith, 14323]
# British_films                                                 [Casino Royale (1967 film), 30584]
# Black-and-white_films                                                 [In Which We Serve, 34492]
# American_Jews                                                              [Billy Wilder, 82160]
# Article_Feedback_Pilot                                                  [United States, 2182418]
# Rivers_of_Romania                                                               [Danube, 628946]
# English-language_albums                                                [Thriller (album), 95141]
# People_from_New_York_City                                              [Eugene O'Neill, 2539133]
# Debut_albums                                                              [Heavy Mental, 204216]
# Windows_games                                                          [Resident Evil 2, 168752]
# Fellows_of_the_Royal_Society                                             [Isaac Newton, 2555447]
# Place_of_birth_missing_(living_people)                              [Simon Baron-Cohen, 2555448]
# Living_people                                                            [Bill Clinton, 7304874]
# The_Football_League_players                                                [George Best, 426592]
# Harvard_University_alumni                                            [John F. Kennedy, 33515951]
# American_military_personnel_of_World_War_II                            [Richard Nixon, 78739265]
# English_footballers                                     [English Football Hall of Fame, 2191920]
# Year_of_birth_missing_(living_people)                                   [Mark David Hall, 22824]
# Major_League_Baseball_pitchers                                              [Babe Ruth, 7378408]
# English_cricketers                                                 [Alec Douglas-Home, 79537994]
# Association_football_forwards                                             [Ferenc Pusks, 325735]
# Association_football_defenders                               [George Young (footballer), 326962]
# Association_football_midfielders                                          [Jzsef Bozsik, 325865]
# Association_football_goalkeepers                    [Goalkeeper (association football), 1553405]
# Year_of_birth_missing                                              [Harry H. Peterson, 34270982]
# Asteroids_named_for_people                                            [25399 Vonnegut, 11898425]
# Year_of_death_missing                                               [William C. Prout, 36417326]
# Main_Belt_asteroids                                                    [Asteroid belt, 14179117]
#
#                                                                                         1       \
# Year_of_birth_unknown                                             [Pausanias (geographer), 12]
# American_film_actors                                                     [Clint Eastwood, 202]
# English-language_films                                            [Terror in the Aisles, 1026]
# Members_of_the_United_Kingdom_Parliament_for_En...                          [Tony Blair, 1741]
# Indian_films                                                    [Three Kings (2011 film), 680]
# American_films                                                              [Easy Rider, 3260]
# English_television_actors                                             [Laurence Olivier, 9614]
# American_television_actors                                                   [Dan Rowan, 7889]
# British_films                                                [Battle of Britain (film), 21004]
# Black-and-white_films                                     [The Cabinet of Dr. Caligari, 31582]
# American_Jews                                                         [Stanley Kubrick, 77283]
# Article_Feedback_Pilot                                                [Academy Award, 1074097]
# Rivers_of_Romania                                                          [Olt River, 112932]
# English-language_albums                             [Dangerous (Michael Jackson album), 79122]
# People_from_New_York_City                                        [Theodore Roosevelt, 2440297]
# Debut_albums                                              [Only Built 4 Cuban Linx..., 129608]
# Windows_games                                                [South Park (video game), 101402]
# Fellows_of_the_Royal_Society                                       [Bertrand Russell, 2386918]
# Place_of_birth_missing_(living_people)                             [John Morton Blum, 2440570]
# Living_people                                                        [Thomas Pynchon, 6926786]
# The_Football_League_players                                             [Brian Clough, 321526]
# Harvard_University_alumni                                              [T. S. Eliot, 23503952]
# American_military_personnel_of_World_War_II                   [Dwight D. Eisenhower, 57120385]
# English_footballers                                                 [Albert Stubbins, 1190213]
# Year_of_birth_missing_(living_people)                                 [Eugene P. Stuart, 9862]
# Major_League_Baseball_pitchers                                        [George Sisler, 1278511]
# English_cricketers                                                   [Beau Brummell, 36419399]
# Association_football_forwards                                               [Garrincha, 73988]
# Association_football_defenders                                     [Giacinto Facchetti, 80092]
# Association_football_midfielders                                         [Billy Milne, 107352]
# Association_football_goalkeepers                              [Dan Lewis (footballer), 392483]
# Year_of_birth_missing                                            [Margaret McNamara, 33800216]
# Asteroids_named_for_people                                           [4148 McCartney, 1190211]
# Year_of_death_missing                                                [Liberty (dog), 27123506]
# Main_Belt_asteroids                                                [12562 Briangrazer, 123224]
#
#                                                                                              2       \
# Year_of_birth_unknown                                                                    [L Bu, 10]
# American_film_actors                                                           [Elvis Presley, 198]
# English-language_films                                                  [The Searchers (film), 951]
# Members_of_the_United_Kingdom_Parliament_for_En...                         [Margaret Thatcher, 564]
# Indian_films                                                              [Life in a... Metro, 502]
# American_films                                                             [The Conversation, 2887]
# English_television_actors                                                     [Michael Caine, 9150]
# American_television_actors                                                 [James Earl Jones, 7623]
# British_films                                                                    [Bullseye!, 20921]
# Black-and-white_films                                          [The Naked Truth (1957 film), 22070]
# American_Jews                                                               [Leonard Maltin, 71971]
# Article_Feedback_Pilot                                                        [Los Angeles, 630690]
# Rivers_of_Romania                                                              [Mure River, 112805]
# English-language_albums                                                        [Bad (album), 78381]
# People_from_New_York_City                                                [Herman Melville, 2271750]
# Debut_albums                                                                  [Purple Onion, 96400]
# Windows_games                                                 [South Park: Chef's Luv Shack, 96400]
# Fellows_of_the_Royal_Society                                                 [Karl Popper, 2277091]
# Place_of_birth_missing_(living_people)                          [Christopher Lehmann-Haupt, 578902]
# Living_people                                                             [George W. Bush, 6722464]
# The_Football_League_players                             [Neil Young (footballer born 1944), 289257]
# Harvard_University_alumni                                        [Charles Sanders Peirce, 15138534]
# American_military_personnel_of_World_War_II                           [Lyndon B. Johnson, 51502598]
# English_footballers                                                       [Herbert Chapman, 392465]
# Year_of_birth_missing_(living_people)                       [Robert L. Simpson (film editor), 2882]
# Major_League_Baseball_pitchers                                                 [Ted Lyons, 1264011]
# English_cricketers                                  [Charles Lennox, 1st Duke of Richmond, 1754052]
# Association_football_forwards                                                 [Silvio Piola, 23489]
# Association_football_defenders                                                    [Roy Paul, 42765]
# Association_football_midfielders                                    [Juan Francisco Barraza, 11752]
# Association_football_goalkeepers                                              [Jack Kelsey, 159615]
# Year_of_birth_missing                                           [Rolling Thunder (person), 3555891]
# Asteroids_named_for_people                                                [904 Rockefellia, 654570]
# Year_of_death_missing                                               [Jack Black (author), 13767542]
# Main_Belt_asteroids                                                           [3428 Roberts, 44686]
#
#                                                                                             3       \
# Year_of_birth_unknown                                                              [Dong Zhuo, 10]
# American_film_actors                                                            [Woody Allen, 196]
# English-language_films                                                       [Apocalypse Now, 853]
# Members_of_the_United_Kingdom_Parliament_for_En...                        [Benjamin Disraeli, 549]
# Indian_films                                                                    [Chori Chori, 449]
# American_films                                                                     [Shrek 2, 2797]
# English_television_actors                                                      [David Niven, 8470]
# American_television_actors                                                 [Hattie McDaniel, 6663]
# British_films                                                         [Henry V (1944 film), 18902]
# Black-and-white_films                                           [A Hard Day's Night (film), 20911]
# American_Jews                                                                 [Jerome Kern, 46564]
# Article_Feedback_Pilot                                                               [CBS, 558330]
# Rivers_of_Romania                                                            [Siret River, 112727]
# English-language_albums                                              [Off the Wall (album), 78329]
# People_from_New_York_City                                                 [William James, 2256254]
# Debut_albums                                        [Business as Usual (Men at Work album), 95144]
# Windows_games                                                         [Grand Theft Auto IV, 88593]
# Fellows_of_the_Royal_Society                                             [Thomas Bowdler, 2271928]
# Place_of_birth_missing_(living_people)                                  [Patrick T. Riley, 449298]
# Living_people                                                              [Barack Obama, 6340152]
# The_Football_League_players                                                   [Matt Busby, 279158]
# Harvard_University_alumni                                         [William S. Burroughs, 13767537]
# American_military_personnel_of_World_War_II                            [Joseph McCarthy, 51107471]
# English_footballers                                                       [George Camsell, 324618]
# Year_of_birth_missing_(living_people)                                         [Milt Woodard, 1964]
# Major_League_Baseball_pitchers                                              [Eddie Smith, 1193675]
# English_cricketers                                              [John Boorman (cricketer), 220721]
# Association_football_forwards                                                 [Ismael Diaz, 11752]
# Association_football_defenders                                              [Lei Clijsters, 18021]
# Association_football_midfielders                                             [Frank Beattie, 4405]
# Association_football_goalkeepers                      [Alex Wilson (footballer born 1908), 156348]
# Year_of_birth_missing                                                   [Thomas Melville, 2274662]
# Asteroids_named_for_people                                               [9622 Terryjones, 428906]
# Year_of_death_missing                                                   [Henry Box Brown, 2302437]
# Main_Belt_asteroids                                                      [153298 Paulmyers, 33410]
#
#                                                                                            4       \
# Year_of_birth_unknown                                                            [Theocritus, 10]
# American_film_actors                                                         [Frank Sinatra, 192]
# English-language_films                                        [The Wizard of Oz (1939 film), 845]
# Members_of_the_United_Kingdom_Parliament_for_En...                     [Neville Chamberlain, 395]
# Indian_films                                                                 [Rafoo Chakkar, 449]
# American_films                                                               [The Shootist, 2718]
# English_television_actors                                                   [Peter Sellers, 8226]
# American_television_actors                                               [David Hasselhoff, 6620]
# British_films                                                             [Maurice (film), 18284]
# Black-and-white_films                                                 [The Ghost Breakers, 20402]
# American_Jews                                                               [George Cukor, 43620]
# Article_Feedback_Pilot                                                     [Warner Bros., 534702]
# Rivers_of_Romania                                                            [Some River, 112710]
# English-language_albums                                                      [Ben (album), 78203]
# People_from_New_York_City                                                 [Harold Bloom, 2243043]
# Debut_albums                                                                 [The Hurting, 95142]
# Windows_games                                              [Grand Theft Auto: San Andreas, 79787]
# Fellows_of_the_Royal_Society                                        [John D. Rockefeller, 654570]
# Place_of_birth_missing_(living_people)                                   [George Monbiot, 386834]
# Living_people                                                              [Don DeLillo, 4448904]
# The_Football_League_players                                                   [Don Revie, 184994]
# Harvard_University_alumni                                             [John Dos Passos, 11589079]
# American_military_personnel_of_World_War_II                               [Byron White, 40598229]
# English_footballers                                                      [Justin Fashanu, 321630]
# Year_of_birth_missing_(living_people)                                          [V. N. Reddy, 450]
# Major_League_Baseball_pitchers                                               [Dizzy Dean, 923812]
# English_cricketers                                  [Jack Meyer (educator and cricketer), 144479]
# Association_football_forwards                                             [Bernab Ferreyra, 8118]
# Association_football_defenders                                              [Daniel Jarque, 3121]
# Association_football_midfielders                                          [Byron Stevenson, 4140]
# Association_football_goalkeepers                                           [Aymor Moreira, 63910]
# Year_of_birth_missing                                                 [Ben Pon (senior), 2224354]
# Asteroids_named_for_people                                                 [1001 Gaussia, 394060]
# Year_of_death_missing                                                   [Craven Laycock, 1538019]
# Main_Belt_asteroids                                                     [8379 Straczynski, 31738]
#
#                                                                                            5       \
# Year_of_birth_unknown                                                               [Yuan Shu, 9]
# American_film_actors                                                      [Steven Spielberg, 190]
# English-language_films                                                         [Dirty Harry, 825]
# Members_of_the_United_Kingdom_Parliament_for_En...                             [John Bright, 365]
# Indian_films                                                                        [Ghulam, 444]
# American_films                                                [Friday the 13th (1980 film), 2294]
# English_television_actors                                                   [Peter Lawford, 7733]
# American_television_actors                                                   [Connie Booth, 6439]
# British_films                                                      [Ella Enchanted (film), 16799]
# Black-and-white_films                                                        [Cluny Brown, 17731]
# American_Jews                                                          [David O. Selznick, 36285]
# Article_Feedback_Pilot                                                          [Germany, 384902]
# Rivers_of_Romania                                                             [Jiu River, 112707]
# English-language_albums                                                      [Thriller 25, 78194]
# People_from_New_York_City                                            [Willem de Kooning, 2204020]
# Debut_albums                                                                   [No Parlez, 95141]
# Windows_games                                                                    [Popotan, 77762]
# Fellows_of_the_Royal_Society                                          [Gottfried Leibniz, 449298]
# Place_of_birth_missing_(living_people)                   [Duncan Campbell (The Guardian), 376080]
# Living_people                                                            [Doris Lessing, 4436963]
# The_Football_League_players                         [Billy Wright (footballer born 1924), 127427]
# Harvard_University_alumni                                              [William Gaddis, 11406086]
# American_military_personnel_of_World_War_II                              [Medgar Evers, 37328983]
# English_footballers                                                      [Willie Maddren, 321537]
# Year_of_birth_missing_(living_people)                                            [Fred Hole, 194]
# Major_League_Baseball_pitchers                                             [Don Drysdale, 873434]
# English_cricketers                                                        [Douglas Bader, 129673]
# Association_football_forwards                                                 [Ferenc Bene, 7417]
# Association_football_defenders                                  [Andrew Watson (footballer), 357]
# Association_football_midfielders                                           [Antonio Puerta, 3311]
# Association_football_goalkeepers                                          [Carlo Ceresoli, 41453]
# Year_of_birth_missing                                                  [Maurice B. Clark, 654570]
# Asteroids_named_for_people                                                   [4150 Starr, 370409]
# Year_of_death_missing                                                   [Ambrose Bierce, 1072332]
# Main_Belt_asteroids                                                           [9885 Linux, 30342]
#
#                                                                                                6       \
# Year_of_birth_unknown                                                                   [Stobaeus, 7]
# American_film_actors                                                            [Marilyn Monroe, 146]
# English-language_films                                                   [The Godfather Part II, 823]
# Members_of_the_United_Kingdom_Parliament_for_En...                             [Michael McGuire, 348]
# Indian_films                                                                      [Disco Dancer, 413]
# American_films                                                                 [The Rains Came, 2250]
# English_television_actors                                                            [Jude Law, 6745]
# American_television_actors                                                        [Magda Gabor, 5688]
# British_films                                                             [War Requiem (film), 16690]
# Black-and-white_films                                                       [Arms and the Man, 16528]
# American_Jews                                                                [Irving Thalberg, 34979]
# Article_Feedback_Pilot                                                         [The Guardian, 372153]
# Rivers_of_Romania                                                               [Bicaz River, 112676]
# English-language_albums                             [Blood on the Dance Floor: HIStory in the Mix,...
# People_from_New_York_City                                                   [Philip Johnson, 2190864]
# Debut_albums                                                                [Switched-On Bach, 77283]
# Windows_games                                                            [Postal (video game), 67044]
# Fellows_of_the_Royal_Society                                           [Carl Friedrich Gauss, 394060]
# Place_of_birth_missing_(living_people)                                [Richard Norton-Taylor, 372597]
# Living_people                                                                    [Bob Dylan, 3555526]
# The_Football_League_players                                                     [Bobby Moore, 107488]
# Harvard_University_alumni                                                       [John Adams, 9691120]
# American_military_personnel_of_World_War_II                                 [John Connally, 36703482]
# English_footballers                                                              [George Kay, 282216]
# Year_of_birth_missing_(living_people)                                       [Hans Jrgen Kiebach, 161]
# Major_League_Baseball_pitchers                                                [Satchel Paige, 830914]
# English_cricketers                                                           [William Worsley, 73769]
# Association_football_forwards                                                  [Billy Halliday, 6828]
# Association_football_defenders                                                  [Alex McLintock, 163]
# Association_football_midfielders                                     [Tommy Burns (footballer), 2816]
# Association_football_goalkeepers                                                  [Lev Yashin, 11160]
# Year_of_birth_missing                                          [John Nelson (police officer), 645758]
# Asteroids_named_for_people                                                [9619 Terrygilliam, 361019]
# Year_of_death_missing                                                         [Bill Gatewood, 830914]
# Main_Belt_asteroids                                                                 [9965 GNU, 29993]
#
#                                                                                                7       \
# Year_of_birth_unknown                                                            [Penda of Mercia, 7]
# American_film_actors                                                               [Henry Fonda, 139]
# English-language_films                                                 [The Aviator (2004 film), 767]
# Members_of_the_United_Kingdom_Parliament_for_En...                               [David Cameron, 336]
# Indian_films                                                               [Akele Hum Akele Tum, 375]
# American_films                                                      [The Big Sleep (1946 film), 2080]
# English_television_actors                                                       [Albert Finney, 6684]
# American_television_actors                                                      [Wesley Snipes, 5341]
# British_films                                                          [The Man Who Never Was, 16501]
# Black-and-white_films                                                            [Road to Rio, 14753]
# American_Jews                                                                 [Michael Curtiz, 28527]
# Article_Feedback_Pilot                                                         [RKO Pictures, 209910]
# Rivers_of_Romania                                                               [Hdate River, 112656]
# English-language_albums                             [History: Past, Present and Future, Book I, 78...
# People_from_New_York_City                                                    [Toni Morrison, 2186354]
# Debut_albums                                                           [Roger McGuinn (album), 70503]
# Windows_games                                                                   [Gears of War, 58318]
# Fellows_of_the_Royal_Society                                                       [Max Born, 387927]
# Place_of_birth_missing_(living_people)                                         [Keith Devlin, 372153]
# Living_people                                                            [George H. W. Bush, 3155428]
# The_Football_League_players                                                  [Jimmy Johnstone, 79994]
# Harvard_University_alumni                                                [William Rehnquist, 9453980]
# American_military_personnel_of_World_War_II                             [Douglas MacArthur, 36417326]
# English_footballers                                                             [Jackie Bray, 279159]
# Year_of_birth_missing_(living_people)                                          [Herbert Strabel, 161]
# Major_League_Baseball_pitchers                                               [Allie Reynolds, 760728]
# English_cricketers                                                           [William Killick, 71387]
# Association_football_forwards                                                 [Billy Houliston, 6117]
# Association_football_defenders                                                  [tienne Mattler, 128]
# Association_football_midfielders                                                  [Miguel Muoz, 1879]
# Association_football_goalkeepers                                                  [Robert Enke, 8144]
# Year_of_birth_missing                                                        [Felipe de Neve, 630690]
# Asteroids_named_for_people                                                   [52665 Brianmay, 154885]
# Year_of_death_missing                                                       [Catherine Pegge, 300592]
# Main_Belt_asteroids                                                         [33179 Arsnewenger, 8247]
#
#                                                                                              8       \
# Year_of_birth_unknown                                                         [Symeon of Durham, 7]
# American_film_actors                                                             [Bette Davis, 138]
# English-language_films                                                          [The Departed, 745]
# Members_of_the_United_Kingdom_Parliament_for_En...  [Arthur Wellesley, 1st Duke of Wellington, 318]
# Indian_films                                                             [Musafir (2004 film), 344]
# American_films                                                                     [Our Gang, 1997]
# English_television_actors                                                     [Ronald Colman, 6591]
# American_television_actors                                                      [Linda Evans, 5182]
# British_films                                                             [The Fixer (film), 15961]
# Black-and-white_films                                             [Kind Hearts and Coronets, 14581]
# American_Jews                                                         [Joseph L. Mankiewicz, 28314]
# Article_Feedback_Pilot                                        [Order of the British Empire, 209554]
# Rivers_of_Romania                                                       [Bega River (Tisza), 14361]
# English-language_albums                                 [Invincible (Michael Jackson album), 78140]
# People_from_New_York_City                                                      [Fred Allen, 638670]
# Debut_albums                                                [The Manhattan Transfer (album), 65336]
# Windows_games                                               [Call of Duty 4: Modern Warfare, 57676]
# Fellows_of_the_Royal_Society                                        [Charles II of England, 300592]
# Place_of_birth_missing_(living_people)                                        [Ed Vulliamy, 372153]
# Living_people                                                               [Jimmy Carter, 3078907]
# The_Football_League_players                                                     [Dixie Dean, 75426]
# Harvard_University_alumni                                        [Willard Van Orman Quine, 7949259]
# American_military_personnel_of_World_War_II                             [Sargent Shriver, 35256958]
# English_footballers                                                          [Bobby Robson, 262725]
# Year_of_birth_missing_(living_people)                                   [Alan Bergman (dancer), 95]
# Major_League_Baseball_pitchers                                             [Walter Johnson, 740361]
# English_cricketers                                                         [Douglas Jardine, 67105]
# Association_football_forwards                                              [Guillermo Stbile, 5606]
# Association_football_defenders                                                  [Willie Savage, 73]
# Association_football_midfielders                                            [Josip Katalinski, 240]
# Association_football_goalkeepers                                        [Vyacheslav Malafeev, 6546]
# Year_of_birth_missing                                                        [James Truitt, 559546]
# Asteroids_named_for_people                                                  [9766 Bradbury, 138558]
# Year_of_death_missing                                                [V. K. Narayana Menon, 228199]
# Main_Belt_asteroids                                                             [793 Arizona, 1426]
#
#                                                                                           9       \
# Year_of_birth_unknown                                                             [Zhang Fei, 6]
# American_film_actors                                                         [Lucille Ball, 138]
# English-language_films                                              [True Grit (1969 film), 734]
# Members_of_the_United_Kingdom_Parliament_for_En...                         [Glenda Jackson, 313]
# Indian_films                                                              [Avvai Shanmughi, 330]
# American_films                                                      [Twilight (2008 film), 1888]
# English_television_actors                                                  [Reginald Owen, 6523]
# American_television_actors                                                  [Alfred Drake, 4999]
# British_films                                                                [Tube Tales, 15619]
# Black-and-white_films                                                  [Julia Misbehaves, 14419]
# American_Jews                                                            [Louis B. Mayer, 26909]
# Article_Feedback_Pilot                                                       [John Ford, 200985]
# Rivers_of_Romania                                                                 [Tisza, 14339]
# English-language_albums                                                 [Got to Be There, 78119]
# People_from_New_York_City                                              [James W. Gerard, 626500]
# Debut_albums                                                              [Yours to Keep, 49451]
# Windows_games                                                  [Half-Life 2: Episode Two, 56990]
# Fellows_of_the_Royal_Society                             [John Howard (prison reformer), 166957]
# Place_of_birth_missing_(living_people)                                    [Alex Brummer, 372153]
# Living_people                                                   [Ivor Grattan-Guinness, 3005599]
# The_Football_League_players                         [Peter Taylor (footballer born 1928), 71749]
# Harvard_University_alumni                                                 [John Updike, 7780170]
# American_military_personnel_of_World_War_II                           [George Wallace, 34347550]
# English_footballers                                                       [Emlyn Hughes, 252047]
# Year_of_birth_missing_(living_people)                                          [Vani Jairam, 90]
# Major_League_Baseball_pitchers                                            [Carl Hubbell, 682669]
# English_cricketers                                                           [Jack Hobbs, 64420]
# Association_football_forwards                                             [Enrique Mateos, 4611]
# Association_football_defenders                                              [Willie Culbert, 73]
# Association_football_midfielders                                          [Roger Albertsen, 115]
# Association_football_goalkeepers                              [Roy Henderson (footballer), 6147]
# Year_of_birth_missing                                          [Paul White (journalist), 558795]
# Asteroids_named_for_people                                               [5656 Oldfield, 135011]
# Year_of_death_missing                                                         [Lai Teck, 209556]
# Main_Belt_asteroids                                                       [34420 Peterpau, 1293]
#
#                                                              ...            \
# Year_of_birth_unknown                                        ...
# American_film_actors                                         ...
# English-language_films                                       ...
# Members_of_the_United_Kingdom_Parliament_for_En...           ...
# Indian_films                                                 ...
# American_films                                               ...
# English_television_actors                                    ...
# American_television_actors                                   ...
# British_films                                                ...
# Black-and-white_films                                        ...
# American_Jews                                                ...
# Article_Feedback_Pilot                                       ...
# Rivers_of_Romania                                            ...
# English-language_albums                                      ...
# People_from_New_York_City                                    ...
# Debut_albums                                                 ...
# Windows_games                                                ...
# Fellows_of_the_Royal_Society                                 ...
# Place_of_birth_missing_(living_people)                       ...
# Living_people                                                ...
# The_Football_League_players                                  ...
# Harvard_University_alumni                                    ...
# American_military_personnel_of_World_War_II                  ...
# English_footballers                                          ...
# Year_of_birth_missing_(living_people)                        ...
# Major_League_Baseball_pitchers                               ...
# English_cricketers                                           ...
# Association_football_forwards                                ...
# Association_football_defenders                               ...
# Association_football_midfielders                             ...
# Association_football_goalkeepers                             ...
# Year_of_birth_missing                                        ...
# Asteroids_named_for_people                                   ...
# Year_of_death_missing                                        ...
# Main_Belt_asteroids                                          ...
#
#                                                              323996  \
# Year_of_birth_unknown                                          None
# American_film_actors                                           None
# English-language_films                                         None
# Members_of_the_United_Kingdom_Parliament_for_En...             None
# Indian_films                                                   None
# American_films                                                 None
# English_television_actors                                      None
# American_television_actors                                     None
# British_films                                                  None
# Black-and-white_films                                          None
# American_Jews                                                  None
# Article_Feedback_Pilot                                         None
# Rivers_of_Romania                                              None
# English-language_albums                                        None
# People_from_New_York_City                                      None
# Debut_albums                                                   None
# Windows_games                                                  None
# Fellows_of_the_Royal_Society                                   None
# Place_of_birth_missing_(living_people)                         None
# Living_people                                       [Guy Fithen, 0]
# The_Football_League_players                                    None
# Harvard_University_alumni                                      None
# American_military_personnel_of_World_War_II                    None
# English_footballers                                            None
# Year_of_birth_missing_(living_people)                          None
# Major_League_Baseball_pitchers                                 None
# English_cricketers                                             None
# Association_football_forwards                                  None
# Association_football_defenders                                 None
# Association_football_midfielders                               None
# Association_football_goalkeepers                               None
# Year_of_birth_missing                                          None
# Asteroids_named_for_people                                     None
# Year_of_death_missing                                          None
# Main_Belt_asteroids                                            None
#
#                                                                      323997  \
# Year_of_birth_unknown                                                  None
# American_film_actors                                                   None
# English-language_films                                                 None
# Members_of_the_United_Kingdom_Parliament_for_En...                     None
# Indian_films                                                           None
# American_films                                                         None
# English_television_actors                                              None
# American_television_actors                                             None
# British_films                                                          None
# Black-and-white_films                                                  None
# American_Jews                                                          None
# Article_Feedback_Pilot                                                 None
# Rivers_of_Romania                                                      None
# English-language_albums                                                None
# People_from_New_York_City                                              None
# Debut_albums                                                           None
# Windows_games                                                          None
# Fellows_of_the_Royal_Society                                           None
# Place_of_birth_missing_(living_people)                                 None
# Living_people                                       [William Todd-Jones, 0]
# The_Football_League_players                                            None
# Harvard_University_alumni                                              None
# American_military_personnel_of_World_War_II                            None
# English_footballers                                                    None
# Year_of_birth_missing_(living_people)                                  None
# Major_League_Baseball_pitchers                                         None
# English_cricketers                                                     None
# Association_football_forwards                                          None
# Association_football_defenders                                         None
# Association_football_midfielders                                       None
# Association_football_goalkeepers                                       None
# Year_of_birth_missing                                                  None
# Asteroids_named_for_people                                             None
# Year_of_death_missing                                                  None
# Main_Belt_asteroids                                                    None
#
#                                                                  323998  \
# Year_of_birth_unknown                                              None
# American_film_actors                                               None
# English-language_films                                             None
# Members_of_the_United_Kingdom_Parliament_for_En...                 None
# Indian_films                                                       None
# American_films                                                     None
# English_television_actors                                          None
# American_television_actors                                         None
# British_films                                                      None
# Black-and-white_films                                              None
# American_Jews                                                      None
# Article_Feedback_Pilot                                             None
# Rivers_of_Romania                                                  None
# English-language_albums                                            None
# People_from_New_York_City                                          None
# Debut_albums                                                       None
# Windows_games                                                      None
# Fellows_of_the_Royal_Society                                       None
# Place_of_birth_missing_(living_people)                             None
# Living_people                                       [David Thwaites, 0]
# The_Football_League_players                                        None
# Harvard_University_alumni                                          None
# American_military_personnel_of_World_War_II                        None
# English_footballers                                                None
# Year_of_birth_missing_(living_people)                              None
# Major_League_Baseball_pitchers                                     None
# English_cricketers                                                 None
# Association_football_forwards                                      None
# Association_football_defenders                                     None
# Association_football_midfielders                                   None
# Association_football_goalkeepers                                   None
# Year_of_birth_missing                                              None
# Asteroids_named_for_people                                         None
# Year_of_death_missing                                              None
# Main_Belt_asteroids                                                None
#
#                                                                    323999  \
# Year_of_birth_unknown                                                None
# American_film_actors                                                 None
# English-language_films                                               None
# Members_of_the_United_Kingdom_Parliament_for_En...                   None
# ...
# English_television_actors                                       None
# American_television_actors                                      None
# British_films                                                   None
# Black-and-white_films                                           None
# American_Jews                                                   None
# Article_Feedback_Pilot                                          None
# Rivers_of_Romania                                               None
# English-language_albums                                         None
# People_from_New_York_City                                       None
# Debut_albums                                                    None
# Windows_games                                                   None
# Fellows_of_the_Royal_Society                                    None
# Place_of_birth_missing_(living_people)                          None
# Living_people                                       [Sophie Cook, 0]
# The_Football_League_players                                     None
# Harvard_University_alumni                                       None
# American_military_personnel_of_World_War_II                     None
# English_footballers                                             None
# Year_of_birth_missing_(living_people)                           None
# Major_League_Baseball_pitchers                                  None
# English_cricketers                                              None
# Association_football_forwards                                   None
# Association_football_defenders                                  None
# Association_football_midfielders                                None
# Association_football_goalkeepers                                None
# Year_of_birth_missing                                           None
# Asteroids_named_for_people                                      None
# Year_of_death_missing                                           None
# Main_Belt_asteroids                                             None
#
#                                                                 324001  \
# Year_of_birth_unknown                                             None
# American_film_actors                                              None
# English-language_films                                            None
# Members_of_the_United_Kingdom_Parliament_for_En...                None
# Indian_films                                                      None
# American_films                                                    None
# English_television_actors                                         None
# American_television_actors                                        None
# British_films                                                     None
# Black-and-white_films                                             None
# American_Jews                                                     None
# Article_Feedback_Pilot                                            None
# Rivers_of_Romania                                                 None
# English-language_albums                                           None
# People_from_New_York_City                                         None
# Debut_albums                                                      None
# Windows_games                                                     None
# Fellows_of_the_Royal_Society                                      None
# Place_of_birth_missing_(living_people)                            None
# Living_people                                       [Sophie Wilcox, 0]
# The_Football_League_players                                       None
# Harvard_University_alumni                                         None
# American_military_personnel_of_World_War_II                       None
# English_footballers                                               None
# Year_of_birth_missing_(living_people)                             None
# Major_League_Baseball_pitchers                                    None
# English_cricketers                                                None
# Association_football_forwards                                     None
# Association_football_defenders                                    None
# Association_football_midfielders                                  None
# Association_football_goalkeepers                                  None
# Year_of_birth_missing                                             None
# Asteroids_named_for_people                                        None
# Year_of_death_missing                                             None
# Main_Belt_asteroids                                               None
#
#                                                                        324002  \
# Year_of_birth_unknown                                                    None
# American_film_actors                                                     None
# English-language_films                                                   None
# Members_of_the_United_Kingdom_Parliament_for_En...                       None
# Indian_films                                                             None
# American_films                                                           None
# English_television_actors                                                None
# American_television_actors                                               None
# British_films                                                            None
# Black-and-white_films                                                    None
# American_Jews                                                            None
# Article_Feedback_Pilot                                                   None
# Rivers_of_Romania                                                        None
# English-language_albums                                                  None
# People_from_New_York_City                                                None
# Debut_albums                                                             None
# Windows_games                                                            None
# Fellows_of_the_Royal_Society                                             None
# Place_of_birth_missing_(living_people)                                   None
# Living_people                                       [Christopher Bramwell, 0]
# The_Football_League_players                                              None
# Harvard_University_alumni                                                None
# American_military_personnel_of_World_War_II                              None
# English_footballers                                                      None
# Year_of_birth_missing_(living_people)                                    None
# Major_League_Baseball_pitchers                                           None
# English_cricketers                                                       None
# Association_football_forwards                                            None
# Association_football_defenders                                           None
# Association_football_midfielders                                         None
# Association_football_goalkeepers                                         None
# Year_of_birth_missing                                                    None
# Asteroids_named_for_people                                               None
# Year_of_death_missing                                                    None
# Main_Belt_asteroids                                                      None
#
#                                                                   324003  \
# Year_of_birth_unknown                                               None
# American_film_actors                                                None
# English-language_films                                              None
# Members_of_the_United_Kingdom_Parliament_for_En...                  None
# Indian_films                                                        None
# American_films                                                      None
# English_television_actors                                           None
# American_television_actors                                          None
# British_films                                                       None
# Black-and-white_films                                               None
# American_Jews                                                       None
# Article_Feedback_Pilot                                              None
# Rivers_of_Romania                                                   None
# English-language_albums                                             None
# People_from_New_York_City                                           None
# Debut_albums                                                        None
# Windows_games                                                       None
# Fellows_of_the_Royal_Society                                        None
# Place_of_birth_missing_(living_people)                              None
# Living_people                                       [Richard Dempsey, 0]
# The_Football_League_players                                         None
# Harvard_University_alumni                                           None
# American_military_personnel_of_World_War_II                         None
# English_footballers                                                 None
# Year_of_birth_missing_(living_people)                               None
# Major_League_Baseball_pitchers                                      None
# English_cricketers                                                  None
# Association_football_forwards                                       None
# Association_football_defenders                                      None
# Association_football_midfielders                                    None
# Association_football_goalkeepers                                    None
# Year_of_birth_missing                                               None
# Asteroids_named_for_people                                          None
# Year_of_death_missing                                               None
# Main_Belt_asteroids                                                 None
#
#                                                                    324004  \
# Year_of_birth_unknown                                                None
# American_film_actors                                                 None
# English-language_films                                               None
# Members_of_the_United_Kingdom_Parliament_for_En...                   None
# Indian_films                                                         None
# American_films                                                       None
# English_television_actors                                            None
# American_television_actors                                           None
# British_films                                                        None
# Black-and-white_films                                                None
# American_Jews                                                        None
# Article_Feedback_Pilot                                               None
# Rivers_of_Romania                                                    None
# English-language_albums                                              None
# People_from_New_York_City                                            None
# Debut_albums                                                         None
# Windows_games                                                        None
# Fellows_of_the_Royal_Society                                         None
# Place_of_birth_missing_(living_people)                               None
# Living_people                                       [Gideon Henderson, 0]
# The_Football_League_players                                          None
# Harvard_University_alumni                                            None
# American_military_personnel_of_World_War_II                          None
# English_footballers                                                  None
# Year_of_birth_missing_(living_people)                                None
# Major_League_Baseball_pitchers                                       None
# English_cricketers                                                   None
# Association_football_forwards                                        None
# Association_football_defenders                                       None
# Association_football_midfielders                                     None
# Association_football_goalkeepers                                     None
# Year_of_birth_missing                                                None
# Asteroids_named_for_people                                           None
# Year_of_death_missing                                                None
# Main_Belt_asteroids                                                  None
#
#                                                                     324005
# Year_of_birth_unknown                                                 None
# American_film_actors                                                  None
# English-language_films                                                None
# Members_of_the_United_Kingdom_Parliament_for_En...                    None
# Indian_films                                                          None
# American_films                                                        None
# English_television_actors                                             None
# American_television_actors                                            None
# British_films                                                         None
# Black-and-white_films                                                 None
# American_Jews                                                         None
# Article_Feedback_Pilot                                                None
# Rivers_of_Romania                                                     None
# English-language_albums                                               None
# People_from_New_York_City                                             None
# Debut_albums                                                          None
# Windows_games                                                         None
# Fellows_of_the_Royal_Society                                          None
# Place_of_birth_missing_(living_people)                                None
# Living_people                                       [Shahryar (singer), 0]
# The_Football_League_players                                           None
# Harvard_University_alumni                                             None
# American_military_personnel_of_World_War_II                           None
# English_footballers                                                   None
# Year_of_birth_missing_(living_people)                                 None
# Major_League_Baseball_pitchers                                        None
# English_cricketers                                                    None
# Association_football_forwards                                         None
# Association_football_defenders                                        None
# Association_football_midfielders                                      None
# Association_football_goalkeepers                                      None
# Year_of_birth_missing                                                 None
# Asteroids_named_for_people                                            None
# Year_of_death_missing                                                 None
# Main_Belt_asteroids                                                   None
#
# [35 rows x 324006 columns]

# %% [markdown]
# In conclusion we present our results in following the requests of the assignment:

# %%
final_rank = []
for i in score_art1.values():
    for j in i:
        final_rank.append(j[0])

# %%
#save sorted_vector_withval list to a file

func.save_list('final_rank.txt', final_rank)

# %%
#load final_rank from file back to a list type

final_rank = func.load_saved_list('final_rank.txt')

# %% [markdown]
# Take a look at the top of our list of ranked articles:

# %%
#take a look to a chunck of our final rank 
final_rank[:30]
# Out:
# ['Diogenes Lartius',
#  'Pausanias (geographer)',
#  'L Bu',
#  'Dong Zhuo',
#  'Theocritus',
#  'Yuan Shu',
#  'Stobaeus',
#  'Penda of Mercia',
#  'Symeon of Durham',
#  'Zhang Fei',
#  'Stephen Dingate',
#  'Edwin, Earl of Mercia',
#  'Stigand',
#  'Valerius Maximus',
#  'Pope Alexander II',
#  'Pope Nicholas III',
#  'Sweyn II of Denmark',
#  'Pope Nicholas II',
#  'Tancred of Hauteville',
#  'Ivan Alexander of Bulgaria',
#  'Nefertiti',
#  'Horemheb',
#  'Sextus Empiricus',
#  'Amasis II',
#  'Devapala',
#  'Pope John VIII',
#  'Sir William Osborne, 8th Baronet',
#  'Joseph N. Langan',
#  'Marcus Licinius Crassus Dives (consul 14 BC)',
#  'Florus']
